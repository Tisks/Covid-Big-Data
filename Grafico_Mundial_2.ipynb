# %% [markdown]
# <a href="https://colab.research.google.com/github/Tisks/Covid-Big-Data/blob/master/Grafico_Mundial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
# from matplotlib import 

df1 = pandas.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_recovered_global.csv&filename=time_series_covid19_recovered_global.csv', sep=',')
df2 = pandas.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
humData = df1.drop(['Province/State','Country/Region','Lat','Long'], axis=1)
humData
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  7/31/20  8/1/20  8/2/20  8/3/20
# 0          0        0        0        0  ...    25509   25509   25510   25669
# 1          0        0        0        0  ...     2952    2961    3018    3031
# 2          0        0        0        0  ...    20537   20988   21419   21901
# 3          0        0        0        0  ...      807     807     807     821
# 4          0        0        0        0  ...      437     460     461     476
# ..       ...      ...      ...      ...  ...      ...     ...     ...     ...
# 248        0        0        0        0  ...      778     782     787     787
# 249        0        0        0        0  ...      862     862     862     863
# 250        0        0        0        0  ...      330     330     330     330
# 251        0        0        0        0  ...     6193    6233    6276    6317
# 252        0        0        0        0  ...      144     171     173     173
#
# [253 rows x 195 columns]

# %%
johnHData = df2.drop(['Province/State','Country/Region','Lat','Long'], axis=1)
johnHData
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  7/31/20  8/1/20  8/2/20  8/3/20
# 0          0        0        0        0  ...    25509   25509   25510   25669
# 1          0        0        0        0  ...     2952    2961    3018    3031
# 2          0        0        0        0  ...    20537   20988   21419   21901
# 3          0        0        0        0  ...      807     807     807     821
# 4          0        0        0        0  ...      437     460     461     476
# ..       ...      ...      ...      ...  ...      ...     ...     ...     ...
# 248        0        0        0        0  ...      778     782     787     787
# 249        0        0        0        0  ...      862     862     862     863
# 250        0        0        0        0  ...      330     330     330     330
# 251        0        0        0        0  ...     6193    6233    6276    6317
# 252        0        0        0        0  ...      144     171     173     173
#
# [253 rows x 195 columns]

# %%
humData[humData.columns].sum()
# Out:
# 1/22/20          28
# 1/23/20          30
# 1/24/20          36
# 1/25/20          39
# 1/26/20          52
#              ...
# 7/30/20    10170650
# 7/31/20    10369140
# 8/1/20     10553585
# 8/2/20     10690555
# 8/3/20     10913000
# Length: 195, dtype: int64

# %%
johnHData[johnHData.columns].sum()
# Out:
# 1/22/20          28
# 1/23/20          30
# 1/24/20          36
# 1/25/20          39
# 1/26/20          52
#              ...
# 7/30/20    10170650
# 7/31/20    10369140
# 8/1/20     10553585
# 8/2/20     10690555
# 8/3/20     10913000
# Length: 195, dtype: int64
