# %% [markdown]
# <a href="https://colab.research.google.com/github/Tisks/Covid-Big-Data/blob/master/Grafico_mundial_3_HumData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_hum=pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_deaths_global.csv&filename=time_series_covid19_deaths_global.csv', sep= ',')
df_hum
# Out:
#     Province/State         Country/Region        Lat  ...  8/1/20  8/2/20  8/3/20
# 0              NaN            Afghanistan  33.939110  ...    1283    1284    1288
# 1              NaN                Albania  41.153300  ...     161     166     172
# 2              NaN                Algeria  28.033900  ...    1223    1231    1239
# 3              NaN                Andorra  42.506300  ...      52      52      52
# 4              NaN                 Angola -11.202700  ...      54      55      58
# ..             ...                    ...        ...  ...     ...     ...     ...
# 261            NaN  Sao Tome and Principe   0.186400  ...      15      15      15
# 262            NaN                  Yemen  15.552727  ...     494     497     499
# 263            NaN                Comoros -11.645500  ...       7       7       7
# 264            NaN             Tajikistan  38.861000  ...      60      61      61
# ...

# %%
agrupado_pais_hum=df_hum.groupby('Country/Region').sum()
agrupado_pais_hum = agrupado_pais_hum.drop(['Lat', 'Long'], axis=1)
Total_Hum = agrupado_pais_hum.sum()
Total_Hum
# Out:
# 1/22/20        17
# 1/23/20        18
# 1/24/20        26
# 1/25/20        42
# 1/26/20        56
#             ...
# 7/30/20    673194
# 7/31/20    679501
# 8/1/20     685062
# 8/2/20     689362
# 8/3/20     693694
# Length: 195, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
p = Total_Hum.plot(figsize =(20,10))
p.set_title('Fallecidos v/s Tiempo: HumData')
p.set_xlabel('Tiempo')
p.set_ylabel('Fallecidos');

# %%
df_JHU=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv', sep= ',')
df_JHU
# Out:
#     Province/State         Country/Region        Lat  ...  8/1/20  8/2/20  8/3/20
# 0              NaN            Afghanistan  33.939110  ...    1283    1284    1288
# 1              NaN                Albania  41.153300  ...     161     166     172
# 2              NaN                Algeria  28.033900  ...    1223    1231    1239
# 3              NaN                Andorra  42.506300  ...      52      52      52
# 4              NaN                 Angola -11.202700  ...      54      55      58
# ..             ...                    ...        ...  ...     ...     ...     ...
# 261            NaN  Sao Tome and Principe   0.186400  ...      15      15      15
# 262            NaN                  Yemen  15.552727  ...     494     497     499
# 263            NaN                Comoros -11.645500  ...       7       7       7
# 264            NaN             Tajikistan  38.861000  ...      60      61      61
# ...

# %%
agrupado_pais_JHU=df_JHU.groupby('Country/Region').sum()
agrupado_pais_JHU = agrupado_pais_JHU.drop(['Lat', 'Long'], axis=1)
Total_JHU = agrupado_pais_hum.sum()
Total_JHU
# Out:
# 1/22/20        17
# 1/23/20        18
# 1/24/20        26
# 1/25/20        42
# 1/26/20        56
#             ...
# 7/30/20    673194
# 7/31/20    679501
# 8/1/20     685062
# 8/2/20     689362
# 8/3/20     693694
# Length: 195, dtype: int64

# %%
p = Total_JHU.plot(figsize =(20,10),color = 'm')
p.set_title('Fallecidos v/s Tiempo: Johns Hopkins University')
p.set_xlabel('Tiempo')
p.set_ylabel('Fallecidos');
