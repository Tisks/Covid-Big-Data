# %% [markdown]
# <a href="https://colab.research.google.com/github/Tisks/Covid-Big-Data/blob/master/Grafico_mundial_3_HumData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_deaths_global.csv&filename=time_series_covid19_deaths_global.csv', sep= ',')
df
# Out:
#     Province/State         Country/Region        Lat  ...  7/31/20  8/1/20  8/2/20
# 0              NaN            Afghanistan  33.939110  ...     1272    1283    1284
# 1              NaN                Albania  41.153300  ...      157     161     166
# 2              NaN                Algeria  28.033900  ...     1210    1223    1231
# 3              NaN                Andorra  42.506300  ...       52      52      52
# 4              NaN                 Angola -11.202700  ...       52      54      55
# ..             ...                    ...        ...  ...      ...     ...     ...
# 261            NaN  Sao Tome and Principe   0.186400  ...       15      15      15
# 262            NaN                  Yemen  15.552727  ...      493     494     497
# 263            NaN                Comoros -11.645500  ...        7       7       7
# 264            NaN             Tajikistan  38.861000  ...       60      60      61
# ...

# %%
#Se quitan las columnas que no nos son utiles para el grafico, se mantiene el pais/region
df1 = df.drop(['Province/State', 'Lat', 'Long'], axis=1)
df1
# Out:
#             Country/Region  1/22/20  1/23/20  ...  7/31/20  8/1/20  8/2/20
# 0              Afghanistan        0        0  ...     1272    1283    1284
# 1                  Albania        0        0  ...      157     161     166
# 2                  Algeria        0        0  ...     1210    1223    1231
# 3                  Andorra        0        0  ...       52      52      52
# 4                   Angola        0        0  ...       52      54      55
# ..                     ...      ...      ...  ...      ...     ...     ...
# 261  Sao Tome and Principe        0        0  ...       15      15      15
# 262                  Yemen        0        0  ...      493     494     497
# 263                Comoros        0        0  ...        7       7       7
# 264             Tajikistan        0        0  ...       60      60      61
# 265                Lesotho        0        0  ...       13      14      19
#
# [266 rows x 195 columns]

# %%
#Se crea un mini dataframe con toda la informacion de un pais que uno busca, en este caso Australia
aust = df1[df1['Country/Region']== "Australia"]
aust
# Out:
#    Country/Region  1/22/20  1/23/20  1/24/20  ...  7/30/20  7/31/20  8/1/20  8/2/20
# 8       Australia        0        0        0  ...        3        3       3       3
# 9       Australia        0        0        0  ...       49       50      50      50
# 10      Australia        0        0        0  ...        0        0       0       0
# 11      Australia        0        0        0  ...        6        6       6       6
# 12      Australia        0        0        0  ...        4        4       4       4
# 13      Australia        0        0        0  ...       13       13      13      13
# 14      Australia        0        0        0  ...      112      116     123     136
# 15      Australia        0        0        0  ...        9        9       9       9
#
# [8 rows x 195 columns]

# %%
#Borramos la columna de pais
aust1 = aust.drop(['Country/Region'], axis=1)
#Se aplica la funcion sum, la cual genera la suma... 
res = aust1.sum()
res
# Out:
# 1/22/20      0
# 1/23/20      0
# 1/24/20      0
# 1/25/20      0
# 1/26/20      0
#           ...
# 7/29/20    189
# 7/30/20    196
# 7/31/20    201
# 8/1/20     208
# 8/2/20     221
# Length: 194, dtype: int64

# %% [markdown]
# Aqui lo ideal seria crear un dato para agregarlo al dataframe final, que sea la informacion obtenida del sum + una columna con el pais.
# Al final el dataframe ideal seria Pais y las fechas, mostrando la cantidad de personas (segun que represente el archivo csv) y graficarlo bonito :3
