# %% [markdown]
# <a href="https://colab.research.google.com/github/Tisks/Covid-Big-Data/blob/master/Grafico_Mundial1_HumData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#importar el archivo
dfHum=pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv', sep= ',')
dfHum
# Out:
#     Province/State         Country/Region        Lat  ...  8/1/20  8/2/20  8/3/20
# 0              NaN            Afghanistan  33.939110  ...   36710   36710   36747
# 1              NaN                Albania  41.153300  ...    5396    5519    5620
# 2              NaN                Algeria  28.033900  ...   30950   31465   31972
# 3              NaN                Andorra  42.506300  ...     925     925     937
# 4              NaN                 Angola -11.202700  ...    1164    1199    1280
# ..             ...                    ...        ...  ...     ...     ...     ...
# 261            NaN  Sao Tome and Principe   0.186400  ...     874     874     874
# 262            NaN                  Yemen  15.552727  ...    1730    1734    1734
# 263            NaN                Comoros -11.645500  ...     386     386     386
# 264            NaN             Tajikistan  38.861000  ...    7451    7495    7538
# ...

# %%
humData = dfHum.drop(['Province/State','Country/Region','Lat','Long'], axis=1)
humData
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  7/31/20  8/1/20  8/2/20  8/3/20
# 0          0        0        0        0  ...    36675   36710   36710   36747
# 1          0        0        0        0  ...     5276    5396    5519    5620
# 2          0        0        0        0  ...    30394   30950   31465   31972
# 3          0        0        0        0  ...      925     925     925     937
# 4          0        0        0        0  ...     1148    1164    1199    1280
# ..       ...      ...      ...      ...  ...      ...     ...     ...     ...
# 261        0        0        0        0  ...      871     874     874     874
# 262        0        0        0        0  ...     1728    1730    1734    1734
# 263        0        0        0        0  ...      378     386     386     386
# 264        0        0        0        0  ...     7409    7451    7495    7538
# 265        0        0        0        0  ...      604     702     718     718
#
# [266 rows x 195 columns]

# %%
humData = humData[humData.columns].sum()
humData
# Out:
# 1/22/20         555
# 1/23/20         654
# 1/24/20         941
# 1/25/20        1434
# 1/26/20        2118
#              ...
# 7/30/20    17309805
# 7/31/20    17599905
# 8/1/20     17850617
# 8/2/20     18079723
# 8/3/20     18282208
# Length: 195, dtype: int64

# %%
humPlot = humData.plot(figsize=(20,5), color='green')
humPlot.set_title('Contagiados v/s tiempo')
humPlot.set_xlabel('Tiempo')
humPlot.tick_params(axis='x', labelrotation=90)
humPlot.set_ylabel('Contagiados')
humPlot.legend(['Contagiados por día']);
